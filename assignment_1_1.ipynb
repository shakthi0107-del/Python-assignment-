# %%
print("hello world")
# Out:
# hello world

# %%
B = float(input("Bill amount: "))
TP = float(input("Tip percentage: "))

Tip = round(B * TP / 100, 2)
total = round(B + Tip, 2)

print("Tip:", Tip, "Total:", total)
# Out:
# Tip: 100.0 Total: 1100.0

# %%
first = input("Enter your first name: ")
last = input("Enter your last name: ")
color = input("Enter your favorite color: ")
print(f"Hello {first} {last}! {color} is a my fav color!")
# Out:
# Hello sakthi vel! blue is a my fav color!

# %%
movies = ["83", "MS Dhoni", "sachin", "Azhar", "chennai28"]
print("First movie:", movies[0])
print("Last movie:", movies[-1])
print("Third movie:", movies[2])
# Out:
# First movie: 83
# Last movie: chennai28
# Third movie: sachin

# %%
nums = list(range(10))
print("First three numbers:", nums[:3])
print("Last four numbers:", nums[-4:])
print("Every third number:", nums[::3])
print("Reversed list:", nums[::-1])
# Out:
# First three numbers: [0, 1, 2]
# Last four numbers: [6, 7, 8, 9]
# Every third number: [0, 3, 6, 9]
# Reversed list: [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]

# %%
fruits = [ ]
for i in range(3):
    fruit = input(f"Enter fruit {i+1}: ")
fruits.append(fruit)
print("Your fruit list:", fruits)
print("First fruit you entered:", fruits[0])
# Out:
# Your fruit list: ['kiwi']
# First fruit you entered: kiwi
